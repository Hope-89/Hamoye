# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df = pd.read_csv('energydata_complete.csv')
# Out:
# --------------------------------
# NameErrorTraceback (most recent call last)
# Cell In[4], line 1
# ----> 1 df = pd.read_csv('energydata_complete.csv')
#
# NameError: name 'pd' is not defined

# %%
simple_linear_reg_df = df[['T2','T6']].sample( 15, random_state=2)

# %%
sns.regplot(x="T2", y="T6",data=simple_linear_reg_df)
# Out:
# <Axes: xlabel='T2', ylabel='T6'>

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()

# %%
from sklearn.linear_model import Ridge

# %%
ridge_reg = Ridge(alpha=0.5)

# %%
ridge_reg.fit(x_train, y_train)
# Out:
# --------------------------------
# NameErrorTraceback (most recent call last)
# Cell In[22], line 1
# ----> 1 ridge_reg.fit(x_train, y_train)
#
# NameError: name 'x_train' is not defined

# %%
from sklearn.metrics import mean_squared_error

# %%
columns_to_calculate = ['T2', 'T6']

# %%
mse = mean_squared_error(df['y_true'], df['y_pred'])
# Out:
# --------------------------------
# NameErrorTraceback (most recent call last)
# Cell In[3], line 1
# ----> 1 mse = mean_squared_error(df['y_true'], df['y_pred'])
#
# NameError: name 'df' is not defined
